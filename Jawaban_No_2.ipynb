# %% [markdown]
# 2. Lakukan clasifikasi dengan menggunakan Algoritma Association Rules dalam soal No. 3 dan hitunglah apabila:
#
# a. min_support=0.2, min_confidence=0.2, min_lift=0.2, min_lenght=2
#
# b. Berapa association rules yang dapat terbentuk dari soal 3a. tersebut?
#
# c. Lakukan export data ke dalam excel terhadap hasil tersebut dan lakukan analisanya!

# %%
import pandas as pd
import numpy as np
from pydrive.auth import GoogleAuth
from mlxtend.frequent_patterns import apriori, association_rules
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
data = pd.read_excel('/content/drive/MyDrive/Classroom/Konsep Aplikasi Datamining A Genap 2023-2024/UAS/dataset soal no.2.xls')
data.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   Barang 1 Barang 2 Barang 3 Barang 4 Barang 5 Barang 6
# 0     Wine    Chips    Bread   Butter     Milk    Apple
# 1     Wine      NaN    Bread   Butter     Milk      NaN
# 2      NaN      NaN    Bread   Butter     Milk      NaN
# 3      NaN    Chips      NaN      NaN      NaN    Apple
# 4     Wine    Chips    Bread   Butter     Milk    Apple

# %%
data.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (101, 6)

# %%
df = data

# Convert the dataset to the required format
df_ohe = df.apply(lambda x: x.astype(str).str.strip()).stack().reset_index(level=1, drop=True)
df_ohe = pd.get_dummies(df_ohe)
df_ohe = df_ohe.groupby(level=0).sum()
df_ohe = df_ohe.astype(bool)  # Convert to boolean type
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Apply apriori algorithm
min_support = 0.2
frequent_itemsets = apriori(df_ohe, min_support=min_support, use_colnames=True)

# Generate the association rules
min_confidence = 0.2
min_lift = 0.2
min_length = 2
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=min_confidence)
rules = rules[(rules['lift'] >= min_lift) & (rules['antecedents'].apply(lambda x: len(x)) >= min_length)]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Simplify the rules for export
rules['antecedents'] = rules['antecedents'].apply(lambda x: ', '.join(list(x)))
rules['consequents'] = rules['consequents'].apply(lambda x: ', '.join(list(x)))
rules = rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']]
rules.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       antecedents consequents   support  confidence      lift
# 42  Bread, Butter       Apple  0.415842    0.840000  1.116316
# 43   Bread, Apple      Butter  0.415842    0.677419  1.103538
# 44  Butter, Apple       Bread  0.415842    0.807692  1.045858
# 48   Bread, Chips       Apple  0.445545    0.789474  1.049169
# 49   Bread, Apple       Chips  0.445545    0.725806  1.004198

# %%
rules.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (500, 5)

# %%
# Save the rules to an Excel file
rules.to_excel('/content/drive/MyDrive/Classroom/Konsep Aplikasi Datamining A Genap 2023-2024/UAS/association_rules.xlsx', index=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
